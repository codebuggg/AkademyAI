# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Figures and Axes

# %%
fig = plt.figure()
fig.add_subplot(2, 2, 1) # 2 rows, 2 cols, first element
fig.add_subplot(2, 2, 4) # 2 rows, 2 cols, last element

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.set_xticks([-2, -1, 0, 1, 2])
ax.set_xticklabels(['-std2', '-std1', 'mean', 'std1', 'std2'])
# Out:
# [Text(0,0,'-std2'),
#  Text(0,0,'-std1'),
#  Text(0,0,'mean'),
#  Text(0,0,'std1'),
#  Text(0,0,'std2')]

# %%
plt.scatter(
    np.random.normal(size=10), np.random.normal(size=10)
)

# %%
plt.plot(
    np.arange(-5, 6, 0.01), np.sin(np.arange(-5, 6, 0.01))
)

# %%
plt.hist(
    np.random.normal(size=100)
)
# Out:
# (array([ 5.,  5., 10., 15., 18., 19., 11.,  8.,  7.,  2.]),
#  array([-1.87114238, -1.453759  , -1.03637563, -0.61899225, -0.20160888,
#          0.2157745 ,  0.63315787,  1.05054125,  1.46792462,  1.88530799,
#          2.30269137]),
#  <a list of 10 Patch objects>)

# %%
plt.pie(
    [0.2, 0.3, 0.5]
)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f519171ba90>,
#   <matplotlib.patches.Wedge at 0x7f519171bf60>,
#   <matplotlib.patches.Wedge at 0x7f51917284a8>],
#  [Text(0.889919,0.646564,''),
#   Text(-0.646564,0.889919,''),
#   Text(1.02989e-07,-1.1,'')])

# %%
pd.Series([0.1, 0.2, 0.3, 0.5]).plot(kind='hist')
