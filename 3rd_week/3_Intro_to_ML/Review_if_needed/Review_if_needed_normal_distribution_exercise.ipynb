# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
xs = np.arange(-10, 10, .01)
ys = np.exp(xs)

# %%
plt.plot(xs, ys)

# %%
# %matplotlib inline
f = plt.figure(); ax=f.add_subplot(1,1,1)

# %%
freq, buckets, *_ = plt.hist(
    np.random.normal(size=1000)
)

# %%
buckets_middle = []
for i in range(len(buckets) - 1):
    buckets_middle.append(buckets[i] + (buckets[i+1] - buckets[i]) / 2)
plt.plot(buckets_middle, freq)



ax.set_title('Normal distribution')
ax.set_xticks([-4, -2, -1, 0, 1, 2, 3, -4])
ax.set_xticklabels([-4, -2, -1, 'mean', 1, 2, 3, -4], rotation=30)
ax.set_xticklabels([-4, -2, -1, 'mean', 1, 2, 3, -4], rotation=30)
buckets_middle
# Out:
# [-2.466768676349721,
#  -1.8205896893802487,
#  -1.1744107024107762,
#  -0.5282317154413035,
#  0.11794727152816886,
#  0.7641262584976414,
#  1.410305245467114,
#  2.0564842324365866,
#  2.702663219406059,
#  3.348842206375531]

# %%
# Out:
# [Text(0.0, 0, '-4'),
#  Text(0.2, 0, '-2'),
#  Text(0.4, 0, '-1'),
#  Text(0.6000000000000001, 0, 'mean'),
#  Text(0.8, 0, '1'),
#  Text(1.0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '-4')]

# %%
freq, buckets, *_ = plt.hist(
    np.random.normal(size=1000)
)
buckets_middle = []
for i in range(len(buckets) - 1):
    buckets_middle.append(buckets[i] + (buckets[i+1] - buckets[i]) / 2)
plt.plot(buckets_middle, freq)
ax.set_title('Normal distribution')
ax.set_xticks([-4, -2, -1, 0, 1, 2, 3, -4])
ax.set_xticklabels([-4, -2, -1, 'mean', 1, 2, 3, -4], rotation=30)
ax.set_xticklabels([-4, -2, -1, 'mean', 1, 2, 3, -4], rotation=30)
buckets_middle
# Out:
# [-3.047590790201405,
#  -2.3650281162178617,
#  -1.6824654422343184,
#  -0.9999027682507753,
#  -0.3173400942672322,
#  0.3652225797163111,
#  1.0477852536998542,
#  1.7303479276833973,
#  2.412910601666941,
#  3.095473275650484]
